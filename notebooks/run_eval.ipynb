# %% [markdown]
# # Mini RAG Evaluation
#
# Запускає evaluation pipeline і записує результати в `data/eval/eval_results.json`.

# %%
import os
import sys
from pathlib import Path

os.environ["EVAL_MAX_QUESTIONS"] = "0"
os.environ["EVAL_RESUME"] = "false"
os.environ["EVAL_SLEEP_SECONDS"] = "0"

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

import importlib
import evaluation.run_eval as run_eval_module
import answering.rag_chain as rag_chain_module

importlib.reload(rag_chain_module)
importlib.reload(run_eval_module)

payload = run_eval_module.run_evaluation()
payload["summary"]
# Out:
# Running 20 questions with full_pipeline and EVAL_SLEEP_SECONDS=0
# Retrieval pipeline: full_pipeline
# Pipeline steps: query_rewrite -> metadata_filter -> hybrid -> rerank
# Total questions: 20
# Total runs: 20
# Average latency: 13.765s
# Source recall@k: 0.900
# Groundedness score: 0.762
# Answer keyword match score: 0.800
#
# 5 good examples:
# - q001: What is FastAPI used for?
# - q016: What does the Python tutorial cover?
# - q005: What are dependencies in FastAPI?
# - q009: What does Pydantic serialization do?
# - q006: What is a Pydantic model?
#
# 5 failed or weak examples:
# - q018: low metric score
# - q008: low metric score
# - q012: low metric score
# - q002: low metric score
# - q017: low metric score
# {'retrieval_pipeline': 'full_pipeline',
#  'pipeline_steps': 'query_rewrite -> metadata_filter -> hybrid -> rerank',
#  'total_questions': 20,
#  'total_runs': 20,
#  'average_latency': 13.764906675000748,
#  'source_recall_at_k': 0.9,
# ...
